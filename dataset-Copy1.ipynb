# %%
import numpy as np
import torch
import os

from torch import optim
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
from torch import nn
from torch.optim import SGD
from torch.autograd import Variable
from torch.utils.data import DataLoader 
from torchvision.models import resnet

from numpy import unravel_index
import gc

from PIL import Image
from os import path
from glob import glob

import random

from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

from config1 import *

# %%
BATCH_SIZE
# Out:
# 12

# %%
IMAGES_PATH="D:/Downloads/VMMRdb"

# %%
dirs = glob(IMAGES_PATH + "/*/")
dirs = [dir.replace("\\", "/") for dir in dirs]
print(dirs)
# Out:
# ['D:/Downloads/VMMRdb/acura_cl_1997/', 'D:/Downloads/VMMRdb/acura_cl_1998/', 'D:/Downloads/VMMRdb/acura_cl_1999/', 'D:/Downloads/VMMRdb/acura_cl_2001/', 'D:/Downloads/VMMRdb/acura_cl_2002/', 'D:/Downloads/VMMRdb/acura_cl_2003/', 'D:/Downloads/VMMRdb/acura_el_1997/', 'D:/Downloads/VMMRdb/acura_el_2001/', 'D:/Downloads/VMMRdb/acura_el_2003/', 'D:/Downloads/VMMRdb/acura_ilx_2013/', 'D:/Downloads/VMMRdb/acura_ilx_2014/', 'D:/Downloads/VMMRdb/acura_integra_1900/', 'D:/Downloads/VMMRdb/acura_integra_1986/', 'D:/Downloads/VMMRdb/acura_integra_1987/', 'D:/Downloads/VMMRdb/acura_integra_1988/', 'D:/Downloads/VMMRdb/acura_integra_1989/', 'D:/Downloads/VMMRdb/acura_integra_1990/', 'D:/Downloads/VMMRdb/acura_integra_1991/', 'D:/Downloads/VMMRdb/acura_integra_1992/', 'D:/Downloads/VMMRdb/acura_integra_1993/', 'D:/Downloads/VMMRdb/acura_integra_1994/', 'D:/Downloads/VMMRdb/acura_integra_1995/', 'D:/Downloads/VMMRdb/acura_integra_1996/', 'D:/Downloads/VMMRdb/acura_integra_1997/', 'D:/Downloads/VMMRdb/acura_integra_1998/', 'D:/Downloads/VMMRdb/acura_integra_1999/', 'D:/Downloads/VMMRdb/acura_integra_2000/', 'D:/Downloads/VMMRdb/acura_integra_2001/', 'D:/Downloads/VMMRdb/acura_kang_2007/', 'D:/Downloads/VMMRdb/acura_legend_1987/', 'D:/Downloads/VMMRdb/acura_legend_1988/', 'D:/Downloads/VMMRdb/acura_legend_1989/', 'D:/Downloads/VMMRdb/acura_legend_1990/', 'D:/Downloads/VMMRdb/acura_legend_1991/', 'D:/Downloads/VMMRdb/acura_legend_1992/', 'D:/Downloads/VMMRdb/acura_legend_1993/', 'D:/Downloads/VMMRdb/acura_legend_1994/', 'D:/Downloads/VMMRdb/acura_legend_1995/', 'D:/Downloads/VMMRdb/acura_legend_1996/', 'D:/Downloads/VMMRdb/acura_legend_2001/', 'D:/Downloads/VMMRdb/acura_legend_2002/', 'D:/Downloads/VMMRdb/acura_mdx_1900/', 'D:/Downloads/VMMRdb/acura_mdx_1996/', 'D:/Downloads/VMMRdb/acura_mdx_2001/', 'D:/Downloads/VMMRd
# %%
num_classes = {}

i = 0
for d in dirs:
    d = d.replace(IMAGES_PATH, "")
    d = d.replace("/", "")
    d = d.replace("\\", "")
    if " " in d:
        d = d.replace(" ", "_")
    num_classes[d] = i
    i+=1

print ("Classes: ")
print (num_classes)
print ("")
# Out:
# Classes:
# {'acura_cl_1997': 0, 'acura_cl_1998': 1, 'acura_cl_1999': 2, 'acura_cl_2001': 3, 'acura_cl_2002': 4, 'acura_cl_2003': 5, 'acura_el_1997': 6, 'acura_el_2001': 7, 'acura_el_2003': 8, 'acura_ilx_2013': 9, 'acura_ilx_2014': 10, 'acura_integra_1900': 11, 'acura_integra_1986': 12, 'acura_integra_1987': 13, 'acura_integra_1988': 14, 'acura_integra_1989': 15, 'acura_integra_1990': 16, 'acura_integra_1991': 17, 'acura_integra_1992': 18, 'acura_integra_1993': 19, 'acura_integra_1994': 20, 'acura_integra_1995': 21, 'acura_integra_1996': 22, 'acura_integra_1997': 23, 'acura_integra_1998': 24, 'acura_integra_1999': 25, 'acura_integra_2000': 26, 'acura_integra_2001': 27, 'acura_kang_2007': 28, 'acura_legend_1987': 29, 'acura_legend_1988': 30, 'acura_legend_1989': 31, 'acura_legend_1990': 32, 'acura_legend_1991': 33, 'acura_legend_1992': 34, 'acura_legend_1993': 35, 'acura_legend_1994': 36, 'acura_legend_1995': 37, 'acura_legend_1996': 38, 'acura_legend_2001': 39, 'acura_legend_2002': 40, 'acura_mdx_1900': 41, 'acura_mdx_1996': 42, 'acura_mdx_2001': 43, 'acura_mdx_2002': 44, 'acura_mdx_2003': 45, 'acura_mdx_2004': 46, 'acura_mdx_2005': 47, 'acura_mdx_2006': 48, 'acura_mdx_2007': 49, 'acura_mdx_2008': 50, 'acura_mdx_2009': 51, 'acura_mdx_2010': 52, 'acura_mdx_2011': 53, 'acura_mdx_2012': 54, 'acura_mdx_2014': 55, 'acura_mdx_2016': 56, 'acura_nsx_2002': 57, 'acura_rdx_2007': 58, 'acura_rdx_2008': 59, 'acura_rdx_2009': 60, 'acura_rdx_2010': 61, 'acura_rdx_2011': 62, 'acura_rdx_2012': 63, 'acura_rdx_2013': 64, 'acura_rdx_2014': 65, 'acura_rl_1996': 66, 'acura_rl_1997': 67, 'acura_rl_1998': 68, 'acura_rl_1999': 69, 'acura_rl_2000': 70, 'acura_rl_2001': 71, 'acura_rl_2002': 72, 'acura_rl_2003': 73, 'acura_rl_2004': 74, 'acura_rl_2005': 75, 'acura_rl_2006': 76, 'acura_rl_2007': 77, 'acura_rl_2008': 78, 'acura_rl_2009': 79, 'acura_rsx_2000': 80, 'acura_rsx_2001': 81, 'acura_rsx_2002': 82, 'acura_rsx_2003': 83, 'acura_rsx_2004': 84, 'acura_rsx_2005': 85, 'acura_rsx_2006': 86, 'acura_rsx_2013': 87, 'acura_slx_1996': 88, 'acura_slx_1998': 89, 'acura_tlx_2015': 90, 'acura_tl_1995': 91, 'acura_tl_1996': 92, 'acura_tl_1997': 93, 'acura_tl_1998': 94, 'acura_tl_1999': 95, 'acura_tl_2000': 96, 'acura_tl_2001': 97, 'acura_tl_2002': 98, 'acura_tl_2003': 99, 'acura_tl_2004': 100, 'acura_tl_2005': 101, 'acura_tl_2006': 102, 'acura_tl_2007': 103, 'acura_tl_2008': 104, 'acura_tl_2009': 105, 'acura_tl_2010': 106, 'acura_tl_2011': 107, 'acura_tl_2012': 108, 'acura_tl_2014': 109, 'acura_tl_2017': 110, 'acura_tsx_2004': 111, 'acura_tsx_2005': 112, 'acura_tsx_2006': 113, 'acura_tsx_2007': 114, 'acura_tsx_2008': 115, 'acura_tsx_2009': 116, 'acura_tsx_2010': 117, 'acura_tsx_2011': 118, 'acura_tsx_2012': 119, 'acura_tsx_2013': 120, 'acura_tsx_wagon_2011': 121, 'acura_vigor_1992': 122, 'acura_vigor_1993': 123, 'acura_vigor_1994': 124, 'acura_xl_1999': 125, 'acura_zdx_2010': 126, 'acura_zdx_2011': 127, 'acura_zdx_2013': 128, 'alfa_romeo_4c_2015': 129, 'alfa_romeo_alfetta_gt_1977': 130, 'alfa_romeo_spider_1978': 131, 'alfa_romeo_spider_1986': 132, 'am_general_hmmvw_1994': 133, 'am_general_hummer_1987': 134, 'am_general_hummer_1992': 135, 'am_general_hummer_h1_1993': 136, 'am_general_jeep_dj-5_1978': 137, 'amc_ambassador_1972': 138, 'amc_amx_1968': 139, 'amc_amx_1969': 140, 'amc_eagle_1985': 141, 'amc_eagle_wagon_1980': 142, 'amc_hornet_1976': 143, 'amc_javelin_1968': 144, 'amc_javelin_1972': 145, 'amc_rambler_1963': 146, 'amc_rambler_1964': 147, 'amc_rambler_1969': 148, 'aston_martin_db9_2005': 149, 'aston_martin_vantage_2008': 150, 'audi_100_1989': 151, 'audi_100_1991': 152, 'audi_100_1994': 153, 'audi_80_1990': 154, 'audi_90_1989': 155, 'audi_90_1990': 156, 'audi_90_1991': 157, 'audi_90_1993': 158, 'audi_a3_2004': 159, 'audi_a3_2006': 160, 'audi_a3_2007': 161, 'audi_a3_2008': 162, 'audi_a3_2009': 163, 'audi_a3_2010': 164, 'audi_a3_2011': 165, 'audi_a3_2012': 166, 'audi_a3_2015': 167, 'audi_a4_1900': 168, 'audi_a4_1996': 169, 'audi_a4_1997': 170, 'audi_a4_1998': 171, 'audi_ ...

# %%
num_classes
# Out:
# {'acura_cl_1997': 0,
#  'acura_cl_1998': 1,
#  'acura_cl_1999': 2,
#  'acura_cl_2001': 3,
#  'acura_cl_2002': 4,
#  'acura_cl_2003': 5,
#  'acura_el_1997': 6,
#  'acura_el_2001': 7,
#  'acura_el_2003': 8,
#  'acura_ilx_2013': 9,
#  'acura_ilx_2014': 10,
#  'acura_integra_1900': 11,
#  'acura_integra_1986': 12,
#  'acura_integra_1987': 13,
#  'acura_integra_1988': 14,
#  'acura_integra_1989': 15,
#  'acura_integra_1990': 16,
#  'acura_integra_1991': 17,
#  'acura_integra_1992': 18,
#  'acura_integra_1993': 19,
#  'acura_integra_1994': 20,
#  'acura_integra_1995': 21,
#  'acura_integra_1996': 22,
#  'acura_integra_1997': 23,
#  'acura_integra_1998': 24,
#  'acura_integra_1999': 25,
#  'acura_integra_2000': 26,
#  'acura_integra_2001': 27,
#  'acura_kang_2007': 28,
#  'acura_legend_1987': 29,
#  'acura_legend_1988': 30,
#  'acura_legend_1989': 31,
#  'acura_legend_1990': 32,
#  'acura_legend_1991': 33,
#  'acura_legend_1992': 34,
#  'acura_legend_1993': 35,
#  'acura_legend_1994': 36,
#  'acura_legend_1995': 37,
#  'acura_legend_1996': 38,
#  'acura_legend_2001': 39,
#  'acura_legend_2002': 40,
#  'acura_mdx_1900': 41,
#  'acura_mdx_1996': 42,
#  'acura_mdx_2001': 43,
#  'acura_mdx_2002': 44,
#  'acura_mdx_2003': 45,
#  'acura_mdx_2004': 46,
#  'acura_mdx_2005': 47,
#  'acura_mdx_2006': 48,
#  'acura_mdx_2007': 49,
#  'acura_mdx_2008': 50,
#  'acura_mdx_2009': 51,
#  'acura_mdx_2010': 52,
#  'acura_mdx_2011': 53,
#  'acura_mdx_2012': 54,
#  'acura_mdx_2014': 55,
#  'acura_mdx_2016': 56,
#  'acura_nsx_2002': 57,
#  'acura_rdx_2007': 58,
#  'acura_rdx_2008': 59,
#  'acura_rdx_2009': 60,
#  'acura_rdx_2010': 61,
#  'acura_rdx_2011': 62,
#  'acura_rdx_2012': 63,
#  'acura_rdx_2013': 64,
#  'acura_rdx_2014': 65,
#  'acura_rl_1996': 66,
#  'acura_rl_1997': 67,
#  'acura_rl_1998': 68,
#  'acura_rl_1999': 69,
#  'acura_rl_2000': 70,
#  'acura_rl_2001': 71,
#  'acura_rl_2002': 72,
#  'acura_rl_2003': 73,
#  'acura_rl_2004': 74,
#  'acura_rl_2005': 75,
#  'acura_rl_2006': 76,
#  'acura_rl_2007': 77,
#  'acura_rl_2008': 78,
#  'acura_rl_2009': 79,
#  'acura_rsx_2000': 80,
#  'acura_rsx_2001': 81,
#  'acura_rsx_2002': 82,
#  'acura_rsx_2003': 83,
#  'acura_rsx_2004': 84,
#  'acura_rsx_2005': 85,
#  'acura_rsx_2006': 86,
#  'acura_rsx_2013': 87,
#  'acura_slx_1996': 88,
#  'acura_slx_1998': 89,
#  'acura_tlx_2015': 90,
#  'acura_tl_1995': 91,
#  'acura_tl_1996': 92,
#  'acura_tl_1997': 93,
#  'acura_tl_1998': 94,
#  'acura_tl_1999': 95,
#  'acura_tl_2000': 96,
#  'acura_tl_2001': 97,
#  'acura_tl_2002': 98,
#  'acura_tl_2003': 99,
#  'acura_tl_2004': 100,
#  'acura_tl_2005': 101,
#  'acura_tl_2006': 102,
#  'acura_tl_2007': 103,
#  'acura_tl_2008': 104,
#  'acura_tl_2009': 105,
#  'acura_tl_2010': 106,
#  'acura_tl_2011': 107,
#  'acura_tl_2012': 108,
#  'acura_tl_2014': 109,
#  'acura_tl_2017': 110,
#  'acura_tsx_2004': 111,
#  'acura_tsx_2005': 112,
#  'acura_tsx_2006': 113,
#  'acura_tsx_2007': 114,
#  'acura_tsx_2008': 115,
#  'acura_tsx_2009': 116,
#  'acura_tsx_2010': 117,
#  'acura_tsx_2011': 118,
#  'acura_tsx_2012': 119,
#  'acura_tsx_2013': 120,
#  'acura_tsx_wagon_2011': 121,
#  'acura_vigor_1992': 122,
#  'acura_vigor_1993': 123,
#  'acura_vigor_1994': 124,
#  'acura_xl_1999': 125,
#  'acura_zdx_2010': 126,
#  'acura_zdx_2011': 127,
#  'acura_zdx_2013': 128,
#  'alfa_romeo_4c_2015': 129,
#  'alfa_romeo_alfetta_gt_1977': 130,
#  'alfa_romeo_spider_1978': 131,
#  'alfa_romeo_spider_1986': 132,
#  'am_general_hmmvw_1994': 133,
#  'am_general_hummer_1987': 134,
#  'am_general_hummer_1992': 135,
#  'am_general_hummer_h1_1993': 136,
#  'am_general_jeep_dj-5_1978': 137,
#  'amc_ambassador_1972': 138,
#  'amc_amx_1968': 139,
#  'amc_amx_1969': 140,
#  'amc_eagle_1985': 141,
#  'amc_eagle_wagon_1980': 142,
#  'amc_hornet_1976': 143,
#  'amc_javelin_1968': 144,
#  'amc_javelin_1972': 145,
#  'amc_rambler_1963': 146,
#  'amc_rambler_1964': 147,
#  'amc_rambler_1969': 148,
#  'aston_martin_db9_2005': 149,
#  'aston_martin_vantage_2008': 150,
#  'audi_100_1989': 151,
#  'audi_100_1991': 152,
#  'audi_100_1994': 153,
#  'audi_80_1990': 154,
#  'audi_90_1989': 155,
#  'audi_90_1990': 156,
#  'audi_90_1991': 157,
#  'audi_90_1993': 158,
#  'audi_a3_2004': 159,
#  'audi_a3_2006': 160,
#  'audi_a3_2007': 161,
#  'audi_a3_2008': 162,
#  'audi_a3_2009': 163,
#  'audi_a3_2010': 164,
#  'audi_a3_2011': 165,
#  'audi_a3_2012': 166,
#  'audi_a3_2015': 167,
#  'audi_a4_1900': 168,
#  'audi_a4_1996': 169,
#  'audi_a4_1997': 170,
#  'audi_a4_1998': 171,
#  'audi_a4_1999': 172,
#  'audi_a4_2000': 173,
#  'audi_a4_2001': 174,
#  'audi_a4_2002': 175,
#  'audi_a4_2003': 176,
#  'audi_a4_2004': 177,
#  'audi_a4_2005': 178,
#  'audi_a4_2006': 179,
#  'audi_a4_2007': 180,
#  'audi_a4_2008': 181,
#  'audi_a4_2009': 182,
#  'audi_a4_2010': 183,
#  'audi_a4_2011': 184,
#  'audi_a4_2012': 185,
#  'audi_a4_2013': 186,
#  'audi_a4_2014': 187,
#  'audi_a4_avant_2006': 188,
#  'audi_a4_avant_2012': 189,
#  'audi_a4_avant_wagon_2001': 190,
#  'audi_a4_cabriolet_1994': 191,
#  'audi_a4_cabriolet_1996': 192,
#  'audi_a4_cabriolet_2004': 193,
#  'audi_a4_cabriolet_2006': 194,
#  'audi_a4_cabriolet_2007': 195,
#  'audi_a4_cabriolet_2009': 196,
#  'audi_a4_wagon_2004': 197,
#  'audi_a4_wagon_2006': 198,
#  'audi_a5_2008': 199,
#  'audi_a5_2009': 200,
#  'audi_a5_2010': 201,
#  'audi_a5_2011': 202,
#  'audi_a5_2012': 203,
#  'audi_a5_2013': 204,
#  'audi_a5_2015': 205,
#  'audi_a5_cabriolet_2011': 206,
#  'audi_a6_1995': 207,
#  'audi_a6_1996': 208,
#  'audi_a6_1997': 209,
#  'audi_a6_1998': 210,
#  'audi_a6_1999': 211,
#  'audi_a6_2000': 212,
#  'audi_a6_2001': 213,
#  'audi_a6_2002': 214,
#  'audi_a6_2003': 215,
#  'audi_a6_2004': 216,
#  'audi_a6_2005': 217,
#  'audi_a6_2006': 218,
#  'audi_a6_2007': 219,
#  'audi_a6_2008': 220,
#  'audi_a6_2009': 221,
#  'audi_a6_2010': 222,
#  'audi_a6_2011': 223,
#  'audi_a6_2012': 224,
#  'audi_a6_2013': 225,
#  'audi_a6_2015': 226,
#  'audi_a6_quattro_1999': 227,
#  'audi_a6_quattro_2000': 228,
#  'audi_a6_quattro_wagon_2001': 229,
#  'audi_a7_2011': 230,
#  'audi_a8_1997': 231,
#  'audi_a8_1998': 232,
#  'audi_a8_1999': 233,
#  'audi_a8_2000': 234,
#  'audi_a8_2001': 235,
#  'audi_a8_2003': 236,
#  'audi_a8_2004': 237,
#  'audi_a8_2005': 238,
#  'audi_a8_2006': 239,
#  'audi_a8_2007': 240,
#  'audi_a8_2008': 241,
#  'audi_a8_2011': 242,
#  'audi_a8_2013': 243,
#  'audi_allroad_2001': 244,
#  'audi_allroad_2002': 245,
#  'audi_allroad_2003': 246,
#  'audi_allroad_2004': 247,
#  'audi_allroad_2005': 248,
#  'audi_allroad_2006': 249,
#  'audi_allroad_2013': 250,
#  'audi_allroad_2014': 251,
#  'audi_cabaret_1996': 252,
#  'audi_cabriolet_1996': 253,
#  'audi_q5_2009': 254,
#  'audi_q5_2010': 255,
#  'audi_q5_2011': 256,
#  'audi_q5_2012': 257,
#  'audi_q5_2015': 258,
#  'audi_q7_2007': 259,
#  'audi_q7_2008': 260,
#  'audi_q7_2009': 261,
#  'audi_q7_2010': 262,
#  'audi_q7_2011': 263,
#  'audi_q7_2012': 264,
#  'audi_q7_2013': 265,
#  'audi_r8_2005': 266,
#  'audi_r8_2009': 267,
#  'audi_r8_2010': 268,
#  'audi_rs4_2007': 269,
#  'audi_s3_2001': 270,
#  'audi_s3_2015': 271,
#  'audi_s4_1993': 272,
#  'audi_s4_2000': 273,
#  'audi_s4_2001': 274,
#  'audi_s4_2002': 275,
#  'audi_s4_2004': 276,
#  'audi_s4_2005': 277,
#  'audi_s4_2006': 278,
#  'audi_s4_2008': 279,
#  'audi_s4_2009': 280,
#  'audi_s4_2010': 281,
#  'audi_s4_2011': 282,
#  'audi_s4_2012': 283,
#  'audi_s4_2014': 284,
#  'audi_s4_avant_2005': 285,
#  'audi_s5_2008': 286,
#  'audi_s5_2009': 287,
#  'audi_s5_2010': 288,
#  'audi_s5_2011': 289,
#  'audi_s5_2012': 290,
#  'audi_s5_2013': 291,
#  'audi_s6_1995': 292,
#  'audi_s6_1999': 293,
#  'audi_s6_2001': 294,
#  'audi_s6_2003': 295,
#  'audi_s6_2004': 296,
#  'audi_s6_2006': 297,
#  'audi_s6_2007': 298,
#  'audi_s6_2008': 299,
#  'audi_s6_2013': 300,
#  'audi_s8_2003': 301,
#  'audi_s8_2008': 302,
#  'audi_s8_2014': 303,
#  'audi_tt_2000': 304,
#  'audi_tt_2001': 305,
#  'audi_tt_2002': 306,
#  'audi_tt_2004': 307,
#  'audi_tt_2006': 308,
#  'audi_tt_2008': 309,
#  'audi_tt_2012': 310,
#  'audi_tt_2013': 311,
#  'audi_tt_2016': 312,
#  'bentley_arnage_1999': 313,
#  'bentley_arnage_2000': 314,
#  'bentley_brooklands_1996': 315,
#  'bentley_continental_2006': 316,
#  'bentley_continental_2012': 317,
#  'bentley_turbo_r_1989': 318,
#  'blakely_bearcat_1977': 319,
#  'bmw_128i_2008': 320,
#  'bmw_128i_2009': 321,
#  'bmw_128i_2010': 322,
#  'bmw_128i_2011': 323,
#  'bmw_128i_2012': 324,
#  'bmw_128i_2013': 325,
#  'bmw_135i_2008': 326,
#  'bmw_135i_2009': 327,
#  'bmw_135i_2010': 328,
#  'bmw_135i_2011': 329,
#  'bmw_135i_convertible_2010': 330,
#  'bmw_318i_1984': 331,
#  'bmw_318i_1985': 332,
#  'bmw_318i_1991': 333,
#  'bmw_318i_1992': 334,
#  'bmw_318i_1993': 335,
#  'bmw_318i_1994': 336,
#  'bmw_318i_1995': 337,
#  'bmw_318i_1996': 338,
#  'bmw_318i_1997': 339,
#  'bmw_318i_1998': 340,
#  'bmw_318i_convertible_1994': 341,
#  'bmw_318i_convertible_1996': 342,
#  'bmw_320i_1979': 343,
#  'bmw_320i_1981': 344,
#  'bmw_320i_1982': 345,
#  'bmw_320i_1983': 346,
#  'bmw_320i_1993': 347,
#  'bmw_320i_1999': 348,
#  'bmw_320i_2003': 349,
#  'bmw_320i_2004': 350,
#  'bmw_320i_2013': 351,
#  'bmw_320i_2014': 352,
#  'bmw_323i_1980': 353,
#  'bmw_323i_1984': 354,
#  'bmw_323i_1998': 355,
#  'bmw_323i_1999': 356,
#  'bmw_323i_2000': 357,
#  'bmw_323i_2001': 358,
#  'bmw_323i_2006': 359,
#  'bmw_323i_2007': 360,
#  'bmw_323i_2008': 361,
#  'bmw_323i_2011': 362,
#  'bmw_325ci_2001': 363,
#  'bmw_325ci_2002': 364,
#  'bmw_325ci_2003': 365,
#  'bmw_325ci_2004': 366,
#  'bmw_325es_1986': 367,
#  'bmw_325e_1984': 368,
#  'bmw_325e_1985': 369,
#  'bmw_325e_1986': 370,
#  'bmw_325e_1987': 371,
#  'bmw_325e_1998': 372,
#  'bmw_325is_1987': 373,
#  'bmw_325is_1994': 374,
#  'bmw_325i_1979': 375,
#  'bmw_325i_1987': 376,
#  'bmw_325i_1989': 377,
#  'buick_rendezvous_2002': 907,
#  'buick_rendezvous_2003': 908,
#  'buick_rendezvous_2004': 909,
#  'buick_rendezvous_2005': 910,
#  'buick_rendezvous_2006': 911,
#  'buick_rendezvous_2007': 912,
#  'buick_riviera_1963': 913,
#  'buick_riviera_1964': 914,
#  'buick_riviera_1965': 915,
#  'buick_riviera_1970': 916,
#  'buick_riviera_1972': 917,
#  'buick_riviera_1973': 918,
#  'buick_riviera_1976': 919,
#  'buick_riviera_1978': 920,
#  'buick_riviera_1979': 921,
#  'buick_riviera_1981': 922,
#  'buick_riviera_1982': 923,
#  'buick_riviera_1983': 924,
#  'buick_riviera_1984': 925,
#  'buick_riviera_1985': 926,
#  'buick_riviera_1989': 927,
#  'buick_riviera_1990': 928,
#  'buick_riviera_1991': 929,
#  'buick_riviera_1992': 930,
#  'buick_riviera_1993': 931,
#  'buick_riviera_1994': 932,
#  'buick_riviera_1995': 933,
#  'buick_riviera_1996': 934,
#  'buick_riviera_1997': 935,
#  'buick_riviera_1998': 936,
#  'buick_riviera_1999': 937,
#  'buick_roadmaster_1938': 938,
#  'buick_roadmaster_1947': 939,
#  'buick_roadmaster_1951': 940,
#  'buick_roadmaster_1992': 941,
#  'buick_roadmaster_1993': 942,
#  'buick_roadmaster_1994': 943,
#  'buick_roadmaster_1995': 944,
#  'buick_roadmaster_1996': 945,
#  'buick_roadmaster_2002': 946,
#  'buick_skylark_1963': 947,
#  'buick_skylark_1964': 948,
#  'buick_skylark_1965': 949,
#  'buick_skylark_1968': 950,
#  'buick_skylark_1970': 951,
#  'buick_skylark_1972': 952,
#  'buick_skylark_1975': 953,
#  'buick_skylark_1976': 954,
#  'buick_skylark_1977': 955,
#  'buick_skylark_1978': 956,
#  'buick_skylark_1991': 957,
#  'buick_skylark_1992': 958,
#  'buick_skylark_1994': 959,
#  'buick_skylark_1995': 960,
#  'buick_skylark_1997': 961,
#  'buick_skylark_1998': 962,
#  'buick_special_1937': 963,
#  'buick_special_1940': 964,
#  'buick_special_1941': 965,
#  'buick_special_1952': 966,
#  'buick_special_1953': 967,
#  'buick_special_1957': 968,
#  'buick_special_1965': 969,
#  'buick_super_1948': 970,
#  'buick_super_1949': 971,
#  'buick_t_type_1984': 972,
#  'buick_terraza_2002': 973,
#  'buick_terraza_2005': 974,
#  'buick_terraza_2006': 975,
#  'buick_terraza_2007': 976,
#  'buick_ultra_2003': 977,
#  'buick_verano_2012': 978,
#  'buick_verano_2013': 979,
#  'buick_verano_2014': 980,
#  'buick_wildcat_1964': 981,
#  'buick_wildcat_1965': 982,
#  'buick_wildcat_1966': 983,
#  'buick_wildcat_1968': 984,
#  'cadillac_allante_1987': 985,
#  'cadillac_allante_1988': 986,
#  'cadillac_allante_1990': 987,
#  'cadillac_allante_1991': 988,
#  'cadillac_allante_1992': 989,
#  'cadillac_allante_1993': 990,
#  'cadillac_allante_1999': 991,
#  'cadillac_ats_2013': 992,
#  'cadillac_ats_2015': 993,
#  'cadillac_brougham_1981': 994,
#  'cadillac_brougham_1986': 995,
#  'cadillac_brougham_1987': 996,
#  'cadillac_brougham_1988': 997,
#  'cadillac_brougham_1989': 998,
#  'cadillac_brougham_1990': 999,
#  ...}

# %%
# read mean and dev. standard pre-computed
m = 0
s = 0
if os.path.isfile('./mean_devstd.txt'):
    m_s = open("mean_devstd.txt", "r").read()
    if "," in m_s:
        m_s = m_s.replace("\n", "")
        m_s = m_s.replace("tensor", "")
        m_s = m_s.replace("(", "")
        m_s = m_s.replace(")", "")
        m_s = m_s.split(",")
        m = torch.Tensor( [float(m_s[0]), float(m_s[1]), float(m_s[2])] )
        s = torch.Tensor( [float(m_s[3]), float(m_s[4]), float(m_s[5])] )
print(m)
# Out:
# tensor([4.7581, 4.7827, 4.7350])

# %%
def get_class(idx):
    #print (num_classes)
    for key in num_classes:
        if idx == num_classes[key]:
            return key
get_class(2)
# Out:
# 'honda_civic_2014'

# %%
def pre():
    train_csv = ""
    test_csv  = ""
    train_csv_supp = []
    test_csv_supp = []
    class_files_training = []
    class_files_testing  = []

    for key in num_classes:
        if " " in key:
            os.rename(IMAGES_PATH+"/"+key, IMAGES_PATH+"/"+key.replace(" ", "_"))
            key = key.replace(" ", "_")  
            
        class_files = glob(IMAGES_PATH+"/"+str(key)+"/*")
        class_files = [w.replace(IMAGES_PATH+"/"+str(key)+"/", "") for w in class_files]
        class_files.sort()

        class_files_training = class_files[: int(len(class_files)*.73)] # get 73% class images for training
        class_files_testing = class_files[int(len(class_files)*.27)+1 :] # get 27% class images for testing

        for f in class_files_training:
            if "," in f or "#" in f or " " in f:
                tmp_f = f.replace(",", "")
                tmp_f = tmp_f.replace("#", "")
                tmp_f = tmp_f.replace(" ", "_")
                tmp_f = tmp_f.replace("\\", "/")
                os.rename(os.path.join(IMAGES_PATH, key, f), os.path.join(IMAGES_PATH, key, tmp_f))
                f = tmp_f
            train_csv_supp.append(f + ","+str(key))

        for f in class_files_testing:
            if "," in f or "#" in f or " " in f:
                tmp_f = f.replace(",", "")
                tmp_f = tmp_f.replace("#", "")
                tmp_f = tmp_f.replace(" ", "_")
                tmp_f = tmp_f.replace("\\", "/")
                os.rename(os.path.join(IMAGES_PATH, key, f), os.path.join(IMAGES_PATH, key, tmp_f))
                f = tmp_f
            test_csv_supp.append(f + ","+str(key))

    random.shuffle(train_csv_supp)
    random.shuffle(test_csv_supp)

    for t in train_csv_supp:
        train_csv += t + "\n"
    
    for t in test_csv_supp:
        test_csv += t + "\n"

    train_csv_file = open("train_file.csv", "w+")
    train_csv_file.write(train_csv)
    train_csv_file.close()

    test_csv_file = open("test_file.csv", "w+")
    test_csv_file.write(test_csv)
    test_csv_file.close()
pre()

# %%
def calc():
        # Algorithms to calculate mean and standard_deviation
    print("Loading dataset...")
    dataset = LocalDataset(IMAGES_PATH, TRAINING_PATH, transform=transforms.ToTensor())
    print("Calculating mean & dev std...")
    
    m = torch.zeros(3) # Mean
    s = torch.zeros(3) # Standard Deviation
    for sample in dataset:
        m += sample['image'].sum(1).sum(1)
        s += ((sample['image']-m.view(3,1,1))**2).sum(1).sum(1)
    m /= len(dataset)*256*144    
    s = torch.sqrt(s/(len(dataset)*256*144))

    print("Calculated mean and standard deviation!")
    str_m = str(m[0])+","+str(m[1])+","+str(m[2])
    str_s = str(s[0])+","+str(s[1])+","+str(s[2])
    file = open("mean_devstd.txt", "w+")
    file.write(str(str_m)+","+str(str_s))
    file.close()
calc()
# Out:
# Loading dataset...
# Calculating mean & dev std...
# Calculated mean and standard deviation!

# %%
class LocalDataset(Dataset):

    def __init__(self, base_path, txt_list, transform=None):
        self.base_path=base_path
        self.images = np.loadtxt(txt_list,delimiter=',',dtype='str') # use np.genfrom() instead of np.loadtxt() to skip errors

        self.transform = transform

    def __getitem__(self, index):
        f,c = self.images[index]

        image_path = path.join(self.base_path + "/" + str(c), f)
        im = Image.open(image_path).convert('RGB')

        if self.transform is not None:
            im = self.transform(im)

        label = num_classes[c]

        return { 'image' : im, 'label':label, 'img_name': f }

    def __len__(self):
        return len(self.images)

# %%
num_classes
# Out:
# {'honda_accord_2015': 0, 'honda_city_2004': 1, 'honda_civic_2014': 2}

# %%
cuda_available=torch.cuda.is_available()

# %%
mean=m
std_dev=s

transform = transforms.Compose([transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean, std_dev)])

training_set = LocalDataset(IMAGES_PATH, TRAINING_PATH, transform=transform)
validation_set = LocalDataset(IMAGES_PATH, VALIDATION_PATH, transform=transform)

training_set_loader = DataLoader(dataset=training_set, batch_size=BATCH_SIZE, num_workers=0, shuffle=True)
validation_set_loader = DataLoader(dataset=validation_set, batch_size=BATCH_SIZE, num_workers=0, shuffle=False)

# %%
def train_model(model_name, model, lr=LEARNING_RATE, epochs=EPOCHS, momentum=MOMENTUM, weight_decay=0, train_loader=training_set_loader, test_loader=validation_set_loader):

    if not os.path.exists(RESULTS_PATH + "/" + model_name):
        os.makedirs(RESULTS_PATH + "/" + model_name)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = SGD(model.parameters(), lr, momentum=momentum, weight_decay=weight_decay)

    loaders = {'train':train_loader, 'test':test_loader}
    losses = {'train':[], 'test':[]}
    accuracies = {'train':[], 'test':[]}

    #testing variables
    y_testing = []
    preds = []

    if USE_CUDA and cuda_available:
        model=model.cuda()

    for e in range(epochs):
        for mode in ['train', 'test']:
            if mode=='train':
                model.train()
            else:
                model.eval()

            epoch_loss = 0
            epoch_acc = 0
            samples = 0

            try:
                for i, batch in enumerate(loaders[mode]):
                    # convert tensor to variable
                    x=Variable(batch['image'], requires_grad=(mode=='train'))
                    y=Variable(batch['label'])

                    if USE_CUDA and cuda_available:
                        x = x.cuda()
                        y = y.cuda()

                    output = model(x)
                    l = criterion(output, y) # loss

                    if mode=='train':
                        l.backward()
                        optimizer.step()
                        optimizer.zero_grad()
                    else:
                        y_testing.extend(y.data.tolist())
                        preds.extend(output.max(1)[1].tolist())
                    
                    if USE_CUDA and cuda_available:
                        acc = accuracy_score(y.data.cuda().cpu().numpy(), output.max(1)[1].cuda().cpu().numpy())
                    else:
                        acc = accuracy_score(y.data, output.max(1)[1])

                    epoch_loss += l.data.item()*x.shape[0] # l.data[0]
                    epoch_acc += acc*x.shape[0]
                    samples += x.shape[0]

                    print ("\r[%s] Epoch %d/%d. Iteration %d/%d. Loss: %0.2f. Accuracy: %0.2f" % \
                        (mode, e+1, epochs, i, len(loaders[mode]), epoch_loss/samples, epoch_acc/samples))

                    if DEBUG and i == 2:
                        break
            except Exception as err:
                print ("\n\n######### ERROR #######")
                print (str(err))
                print ("\n\n######### batch #######")
                print (batch['img_name'])
                print ("\n\n")

            epoch_loss /= samples
            epoch_acc /= samples
            
            losses[mode].append(epoch_loss)
            accuracies[mode].append(epoch_acc)


            print ("\r[%s] Epoch %d/%d. Iteration %d/%d. Loss: %0.2f. Accuracy: %0.2f" % \
                  (mode, e+1, epochs, i, len(loaders[mode]), epoch_loss, epoch_acc))
            
    torch.save(model.state_dict(), str(RESULTS_PATH) + "/" + str(model_name) + "/" + str(model_name) + ".pt")
    return model, (losses, accuracies), y_testing, preds

# %%
def test_model(model_name, model, test_loader = validation_set_loader):
    model.load_state_dict(torch.load(str(RESULTS_PATH) + "/" + str(model_name) + "/" + str(model_name) + ".pt"))

    if USE_CUDA and cuda_available:
        model = model.cuda()

    model.eval()

    preds = []
    gts = []

    #debug
    i = 0
    
    for batch in test_loader:
        x = Variable(batch['image'])

        if USE_CUDA and cuda_available:
            x = x.cuda()
            pred = model(x).data.cuda().cpu().numpy().copy()
        else:
            pred = model(x).data.numpy().copy()

        gt = batch['label'].numpy().copy()
        preds.append(pred)
        gts.append(gt)

        # debug
        if DEBUG:
            if i == 2:
                break
            else:
                i+=1

    return np.concatenate(preds), np.concatenate(gts)

# %%
def write_stats(model_name, y, predictions, gts, predictions2):
    if not os.path.exists(RESULTS_PATH + "/" + model_name):
        os.makedirs(RESULTS_PATH + "/" + model_name)

    acc = accuracy_score(gts, predictions2.argmax(1))
    cm = confusion_matrix(y, predictions)

    if DEBUG:
      score = "00 F1_SCORE 00"
    else:
      score = f1_score(y, predictions, average=None)
    
    file = open(str(RESULTS_PATH) + "/" + str(model_name) + "/" + str(model_name) + "_stats.txt", "w+")
    file.write ("Accuracy: " + str(acc) + "\n\n")
    file.write("Confusion Matrix: \n" + str(cm) + "\n\n")
    file.write("F1 Score: \n" + str(score))
    file.close()

# %%
def plot_logs_classification(model_name, logs):
    if not os.path.exists(RESULTS_PATH + "/" + model_name):
        os.makedirs(RESULTS_PATH + "/" + model_name)

    training_losses, training_accuracies, test_losses, test_accuracies = \
        logs[0]['train'], logs[1]['train'], logs[0]['test'], logs[1]['test']

    plt.figure(figsize=(18,6))
    plt.subplot(121)
    plt.plot(training_losses)
    plt.plot(test_losses)
    plt.legend(['Training Loss','Test Losses'])
    plt.grid()
    plt.subplot(122)
    plt.plot(training_accuracies)
    plt.plot(test_accuracies)
    plt.legend(['Training Accuracy','Test Accuracy'])
    plt.grid()
    #plt.show()
    plt.savefig(str(RESULTS_PATH) + "/" + str(model_name) + "/" + str(model_name) + "_graph.png")

# %%
def train_model_iter(model_name, model, weight_decay=0):

    results = train_model(model_name=model_name, model=model, weight_decay=weight_decay)
    model, loss_acc, y_testing, preds = results[0], results[1], results[2], results[3]

    preds_test, gts = test_model(model_name, model=model)

    write_stats(model_name, y_testing, preds, gts, preds_test)
    plot_logs_classification(model_name, loss_acc)

gc.collect()
# Out:
# 8365

# %%
classes = {"num_classes": len(num_classes)}

resnet152_model = resnet.resnet152(pretrained=False, **classes)
train_model_iter("resnet152", resnet152_model)
# Out:
# C:\Users\Sushant\.conda\envs\my\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Sushant\.conda\envs\my\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# [train] Epoch 1/10. Iteration 0/5. Loss: 0.84. Accuracy: 0.67
# [train] Epoch 1/10. Iteration 1/5. Loss: 0.83. Accuracy: 0.71
# [train] Epoch 1/10. Iteration 2/5. Loss: 1.11. Accuracy: 0.61
# [train] Epoch 1/10. Iteration 3/5. Loss: 1.81. Accuracy: 0.60
# [train] Epoch 1/10. Iteration 4/5. Loss: 1.61. Accuracy: 0.63
# [train] Epoch 1/10. Iteration 4/5. Loss: 1.61. Accuracy: 0.63
# [test] Epoch 1/10. Iteration 0/5. Loss: 583625408512.00. Accuracy: 0.50
# [test] Epoch 1/10. Iteration 1/5. Loss: 583734263808.00. Accuracy: 0.42
# [test] Epoch 1/10. Iteration 2/5. Loss: 535116950186.67. Accuracy: 0.44
# [test] Epoch 1/10. Iteration 3/5. Loss: 529053384704.00. Accuracy: 0.44
# [test] Epoch 1/10. Iteration 4/5. Loss: 568387174400.00. Accuracy: 0.42
# [test] Epoch 1/10. Iteration 4/5. Loss: 568387174400.00. Accuracy: 0.42
# [train] Epoch 2/10. Iteration 0/5. Loss: 3.40. Accuracy: 0.50
# [train] Epoch 2/10. Iteration 1/5. Loss: 2.84. Accuracy: 0.54
# [train] Epoch 2/10. Iteration 2/5. Loss: 2.44. Accuracy: 0.56
# [train] Epoch 2/10. Iteration 3/5. Loss: 2.08. Accuracy: 0.60
# [train] Epoch 2/10. Iteration 4/5. Loss: 2.54. Accuracy: 0.58
# [train] Epoch 2/10. Iteration 4/5. Loss: 2.54. Accuracy: 0.58
# [test] Epoch 2/10. Iteration 0/5. Loss: 1147648999424.00. Accuracy: 0.42
# [test] Epoch 2/10. Iteration 1/5. Loss: 923425406976.00. Accuracy: 0.54
# [test] Epoch 2/10. Iteration 2/5. Loss: 965217878016.00. Accuracy: 0.53
# [test] Epoch 2/10. Iteration 3/5. Loss: 942413987840.00. Accuracy: 0.54
# [test] Epoch 2/10. Iteration 4/5. Loss: 924821791151.16. Accuracy: 0.54
# [test] Epoch 2/10. Iteration 4/5. Loss: 924821791151.16. Accuracy: 0.54
# [train] Epoch 3/10. Iteration 0/5. Loss: 0.63. Accuracy: 0.83
# [train] Epoch 3/10. Iteration 1/5. Loss: 1.04. Accuracy: 0.79
# [train] Epoch 9/10. Iteration 0/5. Loss: 0.11. Accuracy: 1.00
# [train] Epoch 9/10. Iteration 1/5. Loss: 0.34. Accuracy: 0.88
# [train] Epoch 9/10. Iteration 2/5. Loss: 0.38. Accuracy: 0.83
# [train] Epoch 9/10. Iteration 3/5. Loss: 0.47. Accuracy: 0.79
# [train] Epoch 9/10. Iteration 4/5. Loss: 0.52. Accuracy: 0.77
# [train] Epoch 9/10. Iteration 4/5. Loss: 0.52. Accuracy: 0.77
# [test] Epoch 9/10. Iteration 0/5. Loss: 258057200.00. Accuracy: 0.42
# [test] Epoch 9/10. Iteration 1/5. Loss: 204128752.00. Accuracy: 0.54
# [test] Epoch 9/10. Iteration 2/5. Loss: 211185973.33. Accuracy: 0.53
# [test] Epoch 9/10. Iteration 3/5. Loss: 205327060.00. Accuracy: 0.54
# [test] Epoch 9/10. Iteration 4/5. Loss: 203519038.32. Accuracy: 0.54
# [test] Epoch 9/10. Iteration 4/5. Loss: 203519038.32. Accuracy: 0.54
# [train] Epoch 10/10. Iteration 0/5. Loss: 0.80. Accuracy: 0.67
# [train] Epoch 10/10. Iteration 1/5. Loss: 0.78. Accuracy: 0.67
# [train] Epoch 10/10. Iteration 2/5. Loss: 0.70. Accuracy: 0.72
# [train] Epoch 10/10. Iteration 3/5. Loss: 0.64. Accuracy: 0.75
# [train] Epoch 10/10. Iteration 4/5. Loss: 0.62. Accuracy: 0.75
# [train] Epoch 10/10. Iteration 4/5. Loss: 0.62. Accuracy: 0.75
# [test] Epoch 10/10. Iteration 0/5. Loss: 128000600.00. Accuracy: 0.42
# [test] Epoch 10/10. Iteration 1/5. Loss: 101548696.00. Accuracy: 0.54
# [test] Epoch 10/10. Iteration 2/5. Loss: 105247504.00. Accuracy: 0.53
# [test] Epoch 10/10. Iteration 3/5. Loss: 102403354.00. Accuracy: 0.54
# [test] Epoch 10/10. Iteration 4/5. Loss: 101324552.42. Accuracy: 0.54
# [test] Epoch 10/10. Iteration 4/5. Loss: 101324552.42. Accuracy: 0.54

# %%
model_name="resnet152"
model=resnet152_model

# %%
def test_sample(image_path, model=model, model_name=model_name):
    im = Image.open(image_path).convert("RGB")
    im = transform(im)

    if USE_CUDA and cuda_available:
        model = model.cuda()
    model.eval()

    x = Variable(im.unsqueeze(0))

    if USE_CUDA and cuda_available:
        x = x.cuda()
        pred = model(x).data.cuda().cpu().numpy().copy()
    else:
        pred = model(x).data.numpy().copy()

    #print (pred)

    idx_max_pred = np.argmax(pred)
    idx_classes = idx_max_pred % classes["num_classes"]
    #print(get_class(idx_classes))
    return get_class(idx_classes)

# %%
test_sample("C:/Users/Sushant/CarREc/data/honda_accord_2015/2015_Honda_Accord_00A0A_7cURT903w0c_600x450.jpg")
# Out:
# 'honda_accord_2015'

# %%
test_sample("C:/Users/Sushant/CarREc/data/honda_civic_2014/2014_Honda_Civic_Exl_00T0T_1nmOgf2jLTm_600x450.jpg")
# Out:
# 'honda_accord_2015'
